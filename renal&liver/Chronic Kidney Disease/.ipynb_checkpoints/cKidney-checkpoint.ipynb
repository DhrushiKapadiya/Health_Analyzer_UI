# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis
#
# PIMA Diabetes Dataset

# %%
# loading the diabetes dataset to a pandas DataFrame
cKidney_dataset = pd.read_csv('kidney_disease.csv') 
cKidney_dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
cKidney_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
cKidney_dataset.dropna(inplace=True)

# %%
cKidney_dataset
# Out:
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
cKidney_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 3 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              158 non-null    int64
#  1   age             158 non-null    float64
#  2   bp              158 non-null    float64
#  3   sg              158 non-null    float64
#  4   al              158 non-null    float64
#  5   su              158 non-null    float64
#  6   rbc             158 non-null    object
#  7   pc              158 non-null    object
#  8   pcc             158 non-null    object
#  9   ba              158 non-null    object
#  10  bgr             158 non-null    float64
#  11  bu              158 non-null    float64
#  12  sc              158 non-null    float64
#  13  sod             158 non-null    float64
#  14  pot             158 non-null    float64
#  15  hemo            158 non-null    float64
#  16  pcv             158 non-null    object
# ...

# %%
# printing the first 5 rows of the dataset
cKidney_dataset.head()
# Out:
#     id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3    3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9    9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11  11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14  14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20  20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
#
#             ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# 3   notpresent  ...   32   6700  3.9  yes   no   no  poor  yes  yes
# 9   notpresent  ...   29  12100  3.7  yes  yes   no  poor   no  yes
# 11  notpresent  ...   32   4500  3.8  yes  yes   no  poor  yes   no
# 14     present  ...   16  11000  2.6  yes  yes  yes  poor  yes   no
# 20  notpresent  ...   24   9200  3.2  yes  yes  yes  poor  yes  yes
#
#    classification
# 3             ckd
# 9             ckd
# 11            ckd
# 14            ckd
# 20            ckd
#
# [5 rows x 26 columns]

# %%
cKidney_dataset.drop('id',axis=1,inplace=True)

# %%
# number of rows and Columns in this dataset
cKidney_dataset.shape
# Out:
# (158, 25)

# %%
# getting the statistical measures of the data
cKidney_dataset.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000  158.000000
# mean    49.563291   74.050633    1.019873    0.797468    0.253165  131.341772
# std     15.512244   11.175381    0.005499    1.413130    0.813397   64.939832
# min      6.000000   50.000000    1.005000    0.000000    0.000000   70.000000
# 25%     39.250000   60.000000    1.020000    0.000000    0.000000   97.000000
# 50%     50.500000   80.000000    1.020000    0.000000    0.000000  115.500000
# 75%     60.000000   80.000000    1.025000    1.000000    0.000000  131.750000
# max     83.000000  110.000000    1.025000    4.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  158.000000  158.000000  158.000000  158.000000  158.000000
# mean    52.575949    2.188608  138.848101    4.636709   13.687342
# std     47.395382    3.077615    7.489421    3.476351    2.882204
# ...

# %%
cKidney_dataset['classification'].value_counts()
# Out:
# classification
# notckd    115
# ckd        43
# Name: count, dtype: int64

# %%
cKidney_dataset.groupby('classification').mean(numeric_only=True)
# Out:
#                       age         bp        sg        al        su  \
# classification
# ckd             57.279070  80.000000  1.012791  2.930233  0.930233
# notckd          46.678261  71.826087  1.022522  0.000000  0.000000
#
#                        bgr          bu        sc         sod       pot  \
# classification
# ckd             193.930233  104.930233  5.711628  131.023256  5.506977
# notckd          107.939130   33.000000  0.871304  141.773913  4.311304
#
#                      hemo
# classification
# ckd              9.769767
# notckd          15.152174

# %%
cKidney_dataset
# Out:
#       age    bp     sg   al   su       rbc        pc         pcc          ba  \
# 3    48.0  70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 9    53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 11   63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 14   68.0  80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 20   61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...       ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
# ...

# %%
# separating the data and labels
X = cKidney_dataset.drop(columns = 'classification', axis=1)
Y = cKidney_dataset['classification']

# %%
print(X)
# Out:
#       age    bp     sg   al   su       rbc        pc         pcc          ba  \
# 3    48.0  70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 9    53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 11   63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 14   68.0  80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 20   61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...       ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
# ...

# %%
print(Y)
# Out:
# 3         ckd
# 9         ckd
# 11        ckd
# 14        ckd
# 20        ckd
#         ...
# 395    notckd
# 396    notckd
# 397    notckd
# 398    notckd
# 399    notckd
# Name: classification, Length: 158, dtype: object

# %% [markdown]
# Train Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (158, 24) (126, 24) (32, 24)

# %% [markdown]
# Training the Model

# %%
cKidney_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 3 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             158 non-null    float64
#  1   bp              158 non-null    float64
#  2   sg              158 non-null    float64
#  3   al              158 non-null    float64
#  4   su              158 non-null    float64
#  5   rbc             158 non-null    object
#  6   pc              158 non-null    object
#  7   pcc             158 non-null    object
#  8   ba              158 non-null    object
#  9   bgr             158 non-null    float64
#  10  bu              158 non-null    float64
#  11  sc              158 non-null    float64
#  12  sod             158 non-null    float64
#  13  pot             158 non-null    float64
#  14  hemo            158 non-null    float64
#  15  pcv             158 non-null    object
#  16  wc              158 non-null    object
# ...

# %%
classifier = svm.SVC(kernel='linear')

# %%
X_train
# Out:
#       age    bp     sg   al   su       rbc        pc         pcc          ba  \
# 229  59.0  50.0  1.010  3.0  0.0    normal  abnormal  notpresent  notpresent
# 379  62.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 382  48.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 380  59.0  60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 298  34.0  60.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...       ...       ...         ...         ...
# 362  33.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 74   56.0  90.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 242  69.0  70.0  1.010  4.0  3.0    normal  abnormal     present     present
# 256  60.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 313  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
#
# ...

# %%
cKidney_dataset = pd.get_dummies(cKidney_dataset,columns=['htn','dm','cad','appet','pe','ane'], dtype="int")

# %%
# cKidney_dataset.drop('id',axis=1,inplace=True)

# %%
cKidney_dataset
# Out:
#       age    bp     sg   al   su       rbc        pc         pcc          ba  \
# 3    48.0  70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 9    53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 11   63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 14   68.0  80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 20   61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...       ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent  notpresent
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Apply label encoding to all string columns in X
le = LabelEncoder()
for col in X.columns:
    if X[col].dtype == 'object':
        X[col] = le.fit_transform(X[col])

# %%
X = pd.get_dummies(X)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
Y = le.fit_transform(Y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='linear')
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
#training the support vector Machine Classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  1.0

# %%
# accuracy score on the test data
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  1.0

# %%
cKidney_dataset.replace(["normal","abnormal","present","notpresent"],[0,1,1,0] )
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6060\4106027811.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cKidney_dataset.replace(["normal","abnormal","present","notpresent"],[0,1,1,0] )
#       age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...  dm_no  dm_yes  \
# 3    48.0  70.0  1.005  4.0  0.0    0   1    1   0  117.0  ...      1       0
# 9    53.0  90.0  1.020  2.0  0.0    1   1    1   0   70.0  ...      0       1
# 11   63.0  70.0  1.010  3.0  0.0    1   1    1   0  380.0  ...      0       1
# 14   68.0  80.0  1.010  3.0  2.0    0   1    1   1  157.0  ...      0       1
# 20   61.0  80.0  1.015  2.0  0.0    1   1    0   0  173.0  ...      0       1
# ..    ...   ...    ...  ...  ...  ...  ..  ...  ..    ...  ...    ...     ...
# ...

# %%
X.iloc[1]
# Out:
# age       53.00
# bp        90.00
# sg         1.02
# al         2.00
# su         0.00
# rbc        0.00
# pc         0.00
# pcc        1.00
# ba         0.00
# bgr       70.00
# bu       107.00
# sc         7.20
# sod      114.00
# pot        3.70
# hemo       9.50
# pcv        8.00
# wc        11.00
# rc        12.00
# htn        1.00
# dm         1.00
# cad        0.00
# appet      1.00
# pe         0.00
# ane        1.00
# Name: 9, dtype: float64

# %% [markdown]
# Making a Predictive System

# %%
input_data = (53.00,90.00,1.02,2.00,0.00,0.00,0.00,1.00,0.00,70.00,107.00,7.20,114.00,3.70,9.50,8.00,11.00,12.00,1.00,1.00,0.00,1.00,0.00,1.00)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = classifier.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person has not Chronic Kidney')
else:
  print('The person has Chronic Kidney')
# Out:
# [0]
# The person has not Chronic Kidney
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Saving the trained model

# %%
import pickle

# %%
filename = 'cKidney_model.sav'
pickle.dump(classifier, open(filename, 'wb'))

# %%
# loading the saved model
loaded_model = pickle.load(open('cKidney_model.sav', 'rb'))

# %%
input_data = (53,90,1,2,0,0,0,1,0,70,107,7.20,114,3.70,9.50,8,11,12,1,1,0.00,1,0,1)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = classifier.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person has not Chronic Kidney')
else:
  print('The person has Chronic Kidney')
# Out:
# [0]
# The person has not Chronic Kidney
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
for column in X.columns:
  print(column)
# Out:
# age
# bp
# sg
# al
# su
# rbc
# pc
# pcc
# ba
# bgr
# bu
# sc
# sod
# pot
# hemo
# pcv
# wc
# rc
# htn
# dm
# cad
# appet
# pe
# ane

# %%
pd.set_option("display.max_columns",None)
X.iloc[1:100]
# Out:
#       age    bp     sg   al   su  rbc  pc  pcc  ba    bgr     bu   sc    sod  \
# 9    53.0  90.0  1.020  2.0  0.0    0   0    1   0   70.0  107.0  7.2  114.0
# 11   63.0  70.0  1.010  3.0  0.0    0   0    1   0  380.0   60.0  2.7  131.0
# 14   68.0  80.0  1.010  3.0  2.0    1   0    1   1  157.0   90.0  4.1  130.0
# 20   61.0  80.0  1.015  2.0  0.0    0   0    0   0  173.0  148.0  3.9  135.0
# 22   48.0  80.0  1.025  4.0  0.0    1   0    0   0   95.0  163.0  7.7  136.0
# ..    ...   ...    ...  ...  ...  ...  ..  ...  ..    ...    ...  ...    ...
# 325  58.0  80.0  1.020  0.0  0.0    1   1    0   0  100.0   50.0  1.2  140.0
# 326  47.0  60.0  1.020  0.0  0.0    1   1    0   0  109.0   25.0  1.1  141.0
# 327  30.0  60.0  1.025  0.0  0.0    1   1    0   0  120.0   31.0  0.8  150.0
# 329  33.0  60.0  1.025  0.0  0.0    1   1    0   0   80.0   25.0  0.9  146.0
# 331  59.0  70.0  1.025  0.0  0.0    1   1    0   0  130.0   39.0  0.7  147.0
#
# ...
